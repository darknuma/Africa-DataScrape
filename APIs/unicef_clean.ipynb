# %%
import pandas as pd


african_countries = [
    'Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi',
    'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad', 'Comoros',
    'Congo', 'Democratic Republic of the Congo', "Côte d'Ivoire", 'Djibouti',
    'Egypt', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon',
    'Gambia', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
    'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
    'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
    'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia',
    'South Africa', 'South Sudan', 'Sudan', 'Togo', 'Tunisia', 'Uganda',
    'United Republic of Tanzania', 'Zambia', 'Zimbabwe'
]

def filter_african_countries(csv_file):
    df = pd.read_csv(csv_file)
    
    df_filtered = df[df['Geographic area'].isin(african_countries)]
    
    return df_filtered

def main(csv_file_path, output_file_path=None):
    filtered_df = filter_african_countries(csv_file_path)
    
    if output_file_path:
        filtered_df.to_csv(output_file_path, index=False)
    
    return filtered_df


csv_file = 'Cause of death.csv'
output_file = 'unicef_Cause_of_death.csv'

# Run the main function
filtered_african_df = main(csv_file, output_file)

# %%
filtered_african_df
# Out:
#         REF_AREA Reference Area            INDICATOR  \
# 14           AGO         Angola         UIS_SDG_ADMI
# 15           AGO         Angola         UIS_SDG_ADMI
# 16           AGO         Angola         UIS_SDG_ADMI
# 17           AGO         Angola         UIS_SDG_ADMI
# 18           AGO         Angola         UIS_SDG_ADMI
# ...          ...            ...                  ...
# 2721288      ZAF   South Africa  UIS_OPRI_XSPENDP_TS
# 2721289      ZAF   South Africa  UIS_OPRI_XSPENDP_TS
# 2721290      ZMB         Zambia  UIS_OPRI_XSPENDP_TS
# 2721291      ZMB         Zambia  UIS_OPRI_XSPENDP_TS
# 2721292      ZMB         Zambia  UIS_OPRI_XSPENDP_TS
#
#                                                  Indicator SEX    Sex  \
# 14       Administration of a nationally representative ...  _T  Total
# 15       Administration of a nationally representative ...  _T  Total
# 16       Administration of a nationally representative ...  _T  Total
# 17       Administration of a nationally representative ...  _T  Total
# 18       Administration of a nationally representative ...  _T  Total
# ...                                                    ...  ..    ...
# 2721288  Teaching staff compensation as a percentage of...  _T  Total
# 2721289  Teaching staff compensation as a percentage of...  _T  Total
# 2721290  Teaching staff compensation as a percentage of...  _T  Total
# 2721291  Teaching staff compensation as a percentage of...  _T  Total
# 2721292  Teaching staff compensation as a percentage of...  _T  Total
#
#         EDUCATION_LEVEL            Education Level SCHOOL_SUBJECT  \
# 14                   L2  Lower secondary education           MATH
# 15                   L2  Lower secondary education           MATH
# 16                   L2  Lower secondary education           MATH
# 17                   L2  Lower secondary education           MATH
# 18                   L2  Lower secondary education           MATH
# ...                 ...                        ...            ...
# 2721288              _T                      Total             _T
# 2721289              _T                      Total             _T
# 2721290              _T                      Total             _T
# 2721291              _T                      Total             _T
# 2721292              _T                      Total             _T
#
#         School subject  ... Unit of measure DISABILITY Disability status AGE  \
# 14         Mathematics  ...          Number         _T      No breakdown  _T
# 15         Mathematics  ...          Number         _T      No breakdown  _T
# 16         Mathematics  ...          Number         _T      No breakdown  _T
# 17         Mathematics  ...          Number         _T      No breakdown  _T
# 18         Mathematics  ...          Number         _T      No breakdown  _T
# ...                ...  ...             ...        ...               ...  ..
# 2721288          Total  ...               %         _T      No breakdown  _T
# 2721289          Total  ...               %         _T      No breakdown  _T
# 2721290          Total  ...               %         _T      No breakdown  _T
# 2721291          Total  ...               %         _T      No breakdown  _T
# 2721292          Total  ...               %         _T      No breakdown  _T
#
#         Current age TIME_PERIOD OBS_VALUE                     SERIES_ID  \
# 14            Total        2014   0.00000   UIS_SDG_ADMI_L2_MATH_NUMBER
# 15            Total        2015   0.00000   UIS_SDG_ADMI_L2_MATH_NUMBER
# 16            Total        2016   0.00000   UIS_SDG_ADMI_L2_MATH_NUMBER
# 17            Total        2017   0.00000   UIS_SDG_ADMI_L2_MATH_NUMBER
# 18            Total        2018   0.00000   UIS_SDG_ADMI_L2_MATH_NUMBER
# ...             ...         ...       ...                           ...
# 2721288       Total        2019  57.46629  UIS_OPRI_XSPENDP_TS_PUB_PCNT
# 2721289       Total        2020  57.19094  UIS_OPRI_XSPENDP_TS_PUB_PCNT
# 2721290       Total        2004  71.26970  UIS_OPRI_XSPENDP_TS_PUB_PCNT
# 2721291       Total        2015  71.58938  UIS_OPRI_XSPENDP_TS_PUB_PCNT
# 2721292       Total        2016  75.55357  UIS_OPRI_XSPENDP_TS_PUB_PCNT
#
#         OBS_FOOTNOTE DATA_SOURCE
# 14               NaN         UIS
# 15               NaN         UIS
# 16               NaN         UIS
# 17               NaN         UIS
# 18               NaN         UIS
# ...              ...         ...
# 2721288          NaN         UIS
# 2721289          NaN         UIS
# 2721290          NaN         UIS
# 2721291          NaN         UIS
# 2721292          NaN         UIS
#
# [666367 rows x 37 columns]
